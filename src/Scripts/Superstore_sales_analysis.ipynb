# %% [markdown]
# # Superstore Sales Analysis

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Gather and Clean The Data

# %%
data = pd.read_csv("C:\\Users\\Lenovo13\\Downloads\\Superstore Sales Analysis\\src\\Data\\Superstore.csv", encoding="cp1252")

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data = data.drop(['Row ID','Order ID','Customer ID','Postal Code'],axis=1)

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'Country', 'City', 'State', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# Hypothesis Testing and Conclusions

# %% [markdown]
# * Hypothesis 1 : Technology products have the highest profit margin compared to other product categories.
# * Hypothesis 2 : The East region has the highest sales compared to other regions.
# * Hypothesis 3 : Sales are higher during certain months of the year.
# * Hypothesis 4 : Orders with same date shipping have the lowest rate of returned products.
# * Hypothesis 5 : The company's profit is more on weekdays than on weekends.
# * Hypothesis 6 : There is no significant impact of shipping mode on profit margin.
# * Hypothesis 7 : The different customer segments (e.g., Consumer, Corporate, Home Office) exhibit variations in their purchasing behavior and sales contribution.
# * Hypothesis 8 :  There is linear relationship between the discount offered and the quantity of products sold.

# %% [markdown]
# Hypothesis 1 : Technology products have the highest profit margin compared to other product categories.

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'Country', 'City', 'State', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
cat_profit = data.groupby('Category')['Profit'].sum()
cat_profit
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
cat_profit.plot(kind='bar')
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.show()

# %%
# Conclusion : The hypothesis is suppported as technology products have the highest profit margin of the three categories

# %% [markdown]
# Hypothesis 2 : The East region has the highest sales compared to other regions

# %%
cat_sales = data.groupby('Region')['Sales'].sum()
cat_sales
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
cat_sales.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
# Conclusion : The hypothesis is not supported as the west region has the highest sales

# %% [markdown]
# Hypothesis 3 : Sales are higher during certain months of the year

# %%
data['Order Month'] = pd.DatetimeIndex(data['Order Date']).month

# %%
month_sales = data.groupby('Order Month')['Sales'].sum()
month_sales
# Out:
# Order Month
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %%
month_sales.plot(kind='line')
plt.title("Sales during months")
plt.xlabel("Months")
plt.ylabel("Total Sales")
plt.show()

# %%
# Conclusion : The hypothesis is supported as sales are higher during certain months of the year like November , September and March.

# %% [markdown]
# Hypothesis 4 : Orders with same date shipping have the lowest rate of returned products

# %%
total_orders_by_shipping_mode = data.groupby('Ship Mode').size()

returned_orders_by_shipping_mode = data[data['Profit']<0].groupby('Ship Mode').size()

returned_per_by_shipping_mode = (returned_orders_by_shipping_mode/total_orders_by_shipping_mode)*100

print(returned_per_by_shipping_mode)
# Out:
# Ship Mode
# First Class       19.050715
# Same Day          18.047882
# Second Class      15.784062
# Standard Class    19.654826
# dtype: float64

# %%
returned_per_by_shipping_mode.plot(kind='bar')
plt.title("Returned Products Percentage By Shipping Mode")
plt.xlabel("Shipping Mode")
plt.ylabel("Returned Percentage")
plt.show()

# %%
# Conclusion : The hypothesis is not supported as the same day shipping has not the lowest rate of returned products while second class has.

# %% [markdown]
# Hypothesis 5 : The company's profit is more on weekdays than on weekends.

# %%
data['Order Day'] = pd.DatetimeIndex(data['Order Date']).day_name()

# %%
day_profit = data.groupby('Order Day')['Profit'].sum()
day_profit
# Out:
# Order Day
# Friday       46520.8242
# Monday       51511.1146
# Saturday     41277.6202
# Sunday       57129.5120
# Thursday     39683.7512
# Tuesday      35570.3288
# Wednesday    14703.8707
# Name: Profit, dtype: float64

# %%
day_profit.plot(kind='bar')
plt.title("Total Profit by the day of the week")
plt.xlabel("Day of the week")
plt.ylabel("Total Profit")
plt.show()

# %%
# Conclusion : The hypotheis is not  supported as company's profit is higher on weekend compare to week days.

# %% [markdown]
# Hypothesis 6 : There is no significant impact of shipping mode on profit margin

# %%
shipping_modes = data['Ship Mode'].unique()

# %%
shipping_modes
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
groups = [data[data['Ship Mode'] == mode]['Profit'] for mode in shipping_modes]

# %%
from scipy.stats import f_oneway

# %%
# Perform one-way ANOVA test
f_statistic, p_value = f_oneway(*groups)

# %%
alpha = 0.05

# %%
if p_value < alpha:
    print("The choice of shipping mode has a significant impact on profit margin (reject the null hypothesis).")
else:
    print("There is no significant impact of shipping mode on profit margin (fail to reject the null hypothesis).")
# Out:
# There is no significant impact of shipping mode on profit margin (fail to reject the null hypothesis).

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(groups, labels=shipping_modes)
plt.title('Profit Margin Distribution by Shipping Mode')
plt.xlabel('Shipping Mode')
plt.ylabel('Profit Margin')
plt.show()

# %%
# Conclusion : The hypothesis is supported as there is no significant impact of shipping mode on profit margin.

# %% [markdown]
# Hypothesis 7 : The different customer segments (e.g., Consumer, Corporate, Home Office) exhibit variations in their purchasing behavior and sales contribution

# %%
# Group data by customer segment and calculate the total sales for each segment
segment_sales = data.groupby('Segment')['Sales'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(10, 6))
segment_sales.plot(kind='bar', color='skyblue')
plt.title('Sales Contribution by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Total Sales')
plt.show()

# %%
# Conclusion : The hypothesis is supported as the different customer segments (e.g., Consumer, Corporate, Home Office) exhibit variations in their purchasing behavior and sales contribution.

# %% [markdown]
# Hypothesis 8 :  There is linear relationship between the discount offered and the quantity of products sold

# %%
# Create a correlation matrix
correlation_matrix = data[['Discount', 'Quantity']].corr()

# Create a heatmap to visualize the correlation
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap: Product Discount vs. Quantity Sold')

plt.show()

# %%
correlation_matrix = data[['Discount', 'Quantity']].corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#           Discount  Quantity
# Discount  1.000000  0.008623
# Quantity  0.008623  1.000000

# %%
# Conclusion : The hypothesis is not supported as there is a weak or negligible linear relationship between the discount offered and the quantity of products sold.

# %% [markdown]
# Pair Plot of Sales, Discount, Profit and Quantity columns of the dataset

# %%
# Select the relevant numerical variables for the pair plot
numerical_data = data[['Sales', 'Quantity', 'Discount', 'Profit']]

# Create a pair plot
sns.pairplot(numerical_data)
plt.suptitle('Pair Plot: Numerical Variables', y=1.02)
plt.show()
